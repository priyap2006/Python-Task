# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score
df =pd.read_csv("Advertising.csv")
print(df.head())
X = df[['TV','Radio','Newspaper']]
Y = df['Sales']
model = LinearRegression()
model.fit(X, Y)
Y_pred = model.predict(X)

print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean squared error:",mean_squared_error)
print("r2_score:" , r2_score(Y,Y_pred))
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# Coefficient: [ 0.04576465  0.18853002 -0.00103749]
# Intercept: 2.938889369459412
# Mean squared error: <function mean_squared_error at 0x0000018037ADFEC0>
# r2_score: 0.8972106381789522

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score
df =pd.read_csv("SalaryData.csv")
df = df.dropna()
print(df.head())
X = df[['Years of Experience']]
Y = df['Salary']
model = LinearRegression()
model.fit(X,Y)
Y_pred = model.predict(X)

print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean squared error:",mean_squared_error(Y,Y_pred))
print("r2_score:" , r2_score(Y,Y_pred))
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# Coefficient: [6844.51051448]
# Intercept: 31921.21691704422
# Mean squared error: 312090043.799001
# r2_score: 0.865528278393677

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score
df =pd.read_csv("winequalityN.csv")
df['type'] =df['type'].map({'red':0,'white':1})
df=df.fillna(df.mean())
print(df.head())
X = df.drop('quality',axis=1)
Y = df['quality']
model = LinearRegression()
model.fit(X, Y)
Y_pred = model.predict(X)

print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean squared error:",mean_squared_error(Y,Y_pred))
print("r2_score:" , r2_score(Y,Y_pred))
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1            7.0              0.27         0.36            20.7
# 1     1            6.3              0.30         0.34             1.6
# 2     1            8.1              0.28         0.40             6.9
# 3     1            7.2              0.23         0.32             8.5
# 4     1            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6
# Coefficient: [-3.60856850e-01  8.48257123e-02 -1.48894237e+00 -6.07625096e-02
#   6.24849077e-02 -7.69513037e-01  4.93139670e-03 -1.41086914e-03
#  -1.04005678e+02  4.95887418e-01  7.24766700e-01  2.22394643e-01]
# Intercept: 104.85893116386372
# Mean squared error: 0.5363604337288178
# r2_score: 0.2965371749024416

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score
df =pd.read_csv("HousingData.csv")
df=df.fillna(df.mean())
print(df.head())
X = df.drop('MEDV',axis=1)
Y = df['MEDV']
model = LinearRegression()
model.fit(X, Y)
Y_pred = model.predict(X)

print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean squared error:",mean_squared_error(Y,Y_pred))
print("r2_score:" , r2_score(Y,Y_pred))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B      LSTAT  MEDV
# 0  396.90   4.980000  24.0
# 1  396.90   9.140000  21.6
# 2  392.83   4.030000  34.7
# 3  394.63   2.940000  33.4
# 4  396.90  12.715432  36.2
# Coefficient: [-1.10561120e-01  4.04425629e-02 -3.92368349e-02  3.04684576e+00
#  -1.67520152e+01  4.10931460e+00 -1.06410218e-02 -1.49068736e+00
#   2.68831450e-01 -1.05849144e-02 -9.28659668e-01  9.34575526e-03
#  -4.64990510e-01]
# Intercept: 34.02554723522326
# Mean squared error: 22.674207888327313
# r2_score: 0.7314104821117173
